# %%
def printTable(start,end,step):
#Implement Your Code Here
    for i in range(start, end+1, step):
        c = int((i-32)*5/9)
        print(str(i) + " " + str(c))


s = int(input())
e = int(input())
step = int(input())
printTable(s,e,step)
# Out:
# -50
# 160
# 2
# -50 -45
# -48 -44
# -46 -43
# -44 -42
# -42 -41
# -40 -40
# -38 -38
# -36 -37
# -34 -36
# -32 -35
# -30 -34
# -28 -33
# -26 -32
# -24 -31
# -22 -30
# -20 -28
# -18 -27
# -16 -26
# -14 -25
# -12 -24
# -10 -23
# -8 -22
# -6 -21
# -4 -20
# -2 -18
# 0 -17
# 2 -16
# 4 -15
# 6 -14
# 8 -13
# 10 -12
# 12 -11
# 14 -10
# 16 -8
# 18 -7
# 20 -6
# 22 -5
# 24 -4
# 26 -3
# 28 -2
# 30 -1
# 32 0
# 34 1
# 36 2
# 38 3
# 40 4
# 42 5
# 44 6
# 46 7
# 48 8
# 50 10
# 52 11
# 54 12
# 56 13
# 58 14
# 60 15
# 62 16
# 64 17
# 66 18
# 68 20
# 70 21
# 72 22
# 74 23
# 76 24
# 78 25
# 80 26
# 82 27
# 84 28
# 86 30
# 88 31
# 90 32
# 92 33
# 94 34
# 96 35
# 98 36
# 100 37
# 102 38
# 104 40
# 106 41
# 108 42
# 110 43
# 112 44
# 114 45
# 116 46
# 118 47
# 120 48
# 122 50
# 124 51
# 126 52
# 128 53
# 130 54
# 132 55
# 134 56
# 136 57
# 138 58
# 140 60
# 142 61
# 144 62
# 146 63
# 148 64
# 150 65
# 152 66
# 154 67
# 156 68
# 158 70
# 160 71
